# %% [markdown]
# 6.online course enrollment comparision using sets

# %%
python=set(input("enter python students \n").split())
java=set(input("enter java students\n").split())
common=python&java
print("students enrolled in botn courses:",common)
# Out:
# enter python students
# Ravi Anita Kumar
# enter java students
# Anita Rahul Ravi
# students enrolled in botn courses: {'Ravi', 'Anita'}

# %% [markdown]
# 7. library book avalibility using list

# %%
books=input ("enter avaliable books\n").split()
req =input ("enter  book name\n")
if req in books:
  print ("book avaliable")
else:
    print("book is not avaliable")
# Out:
# enter avaliable books
# python java c
# enter  book name
# python
# book avaliable

# %% [markdown]
# 8.duplicate phone numbers detection using set

# %%
phones=input ("enter phone numbers\n").split()
if len (phones)==len(set(phones)):
  print ("no duplicates found")
else:
    print("duplicates phone number found")
# Out:
# enter phone numbers
# 98765 91234 98765
# duplicates phone number found

# %% [markdown]
# 9.shopping cart validation using list

# %%
stock=set(input("enter stock items\n").split())
cart=input("enter cart items\n").split()
for item in cart:
  if item not in stock:
    print(item,"is not avaliable")
# Out:
# enter stock items
# rice sugar oil
# enter cart items
# rice oil milk
# milk is not avaliable

# %% [markdown]
# 10.examination rank list using tuple

# %%
ranks=tuple(input("enter rank holders\n").split())
print("topper=",ranks[0])
# Out:
# enter rank holders
# anita ravi kumar
# topper= anita

# %% [markdown]
# experiment=04
# 1.calculate total marks of a student using dictionary values

# %%
marks={"marks":80,"science":75,"english":70}
total=0
for m in marks . values():
  total+=m
print("total marks =",total)
# Out:
# total marks = 225

# %% [markdown]
# 2.id3entify subject with highest marks using dictionary

# %%
marks={"maths":80,"science":90,"english":70}
highest=max(marks,key=marks.get)
print("highest marks subject=",highest)
# Out:
# highest marks subject= science

# %% [markdown]
# 3.count number of products in each category

# %%
products={"pen":"stationary","book":"stationary","soap":"grocery","rice":"grocery"}
count={}
for cat in products.values():
  count[cat]=count.get(cat,0)+1
print(count)
# Out:
# {'stationary': 2, 'grocery': 2}

# %% [markdown]
# 4.calculate average temperature using dictionary

# %%
temp={"mon":30,"tue":32,"wed":31,"thu":33,"fri":30}
avg=sum(temp.values())/len(temp)
print("average temperature=",avg)
# Out:
# average temperature= 31.2

# %% [markdown]
# 5.identify absent students using dictionary status

# %%
attendance={"ravi":"present","anita":"absent","kumar":"present","meena":"absent"}
for name,status in attendance .items():
  if status =="absent":
    print(name)
# Out:
# anita
# meena

# %% [markdown]
# 6.calculate electricity bill for multiple cinsumers

# %%
units={"ravi":120,"anita":90,"kumar":150}
rate=5
for name ,u in units.items():
  print(name,"bill=",u*rate)
# Out:
# ravi bill= 600
# anita bill= 450
# kumar bill= 750

# %% [markdown]
# 7.find employees eligible for bonus using dictionary

# %%
salary={"ravi":28000,"anita":35000,"kumar":22000}
for name,amt in salary.items():
  if amt>=30000:
    print(name,"eligible for bonus")
# Out:
# anita eligible for bonus

# %% [markdown]
# 8.calculate total sales using dictionary

# %%
sales={"pen":500,"book":1200,"bag":2000}
total=sum(sales.values())
print("total sales=",total)
# Out:
# total sales= 3700

# %% [markdown]
# 9.convert marks to grade using dictionery mapping

# %%
grade={"A":80,"B":60,"C":40}
mark=int(input("enter marks\n"))
if mark>=grade["A"]:
  print("grade a")
elif mark>=grade["B"]:
  print("gradeB")
elif mark>=grade["C"]:
    print("grade C")
else:
   print("fail")
# Out:
# enter marks
# 85
# grade a

# %% [markdown]
# 10.find total working hours using dictionary

# %%
hours={"mon":8,"tue":7,"wed":8,"thu":6,"fri":7}
total=sum(hours.values())
print("total working hours =",total)
# Out:
# total working hours = 36

# %% [markdown]
# ex.no:5
# 1.validate users input using exception handling

# %%
try:
  age=int(input("enter age\n"))
  print("valid age:",age)

except ValueError:
  print("invalid input! age must be a number")
# Out:
# enter age
# 25
# valid age: 25

# %% [markdown]
# 2.division operation with zero division handling

# %%
try:
  a=int(input("enter numerator\n"))
  b=int(input("enter denominator\n"))
  print("result =",a/b)
except ZeroDivisionError:
  print("error: division zero is not allowed")
# Out:
# enter numerator
# 10
# enter denominator
# 0
# error: division zero is not allowed

# %% [markdown]
# 3.username lengthy validation using string operation

# %%
username=input("enter username\n")
if len (username)>=6:
  print("Valid username")
else:
  print("username too short")
# Out:
# enter username
# admin
# username too short

# %% [markdown]
# 4.check whether an email id contain'@'symbol

# %%
email=input("enter email id\n")
if "@"in email:
  print("valid email id")
else:
  print("invalid email id")
# Out:
# enter email id
# usergmail.com
# invalid email id

# %% [markdown]
# 5.password strength check using string method

# %%
pwd=input("enter password\n")
if len (pwd)>=8 and any(ch.isdigit() for ch in pwd):
  print("strong password")
else:
  print("weak password")
# Out:
# enter password
# pass 123
# strong password

# %% [markdown]
# 6.file name extension check using string split

# %%
fname=input("enter file name\n")
ext=fname.split(".")[-1]
print("file extension =",ext)
# Out:
# enter file name
# report.pdf
# file extension = pdf

# %% [markdown]
# 7.count words in a sentence using string method

# %%
sentence=input("enter sentence \n ")
words=sentence.split()
print("number of words =",len(words))
# Out:
# enter sentence
#  python is easy to learn
# number of words = 5

# %% [markdown]
# 8.ATM withdrawl validation using excepton handling

# %%
balance=5000
try:
  amt=int(input("enter withdrawl amount\n"))
  if amt<=balance:
    print("transaction successful")
  else:
      print("insufficient balance")
except ValueError:
  print("invalid amount entered")
# Out:
# enter withdrawl amount
# abc
# invalid amount entered

# %% [markdown]
# 9.replace spaces with hyphen in a string

# %%
text=input("enter text\n")
print("modified text =",text.replace(" ","-"))
# Out:
# enter text
# data science lab
# modified text = data-science-lab

# %% [markdown]
# 10.validate mobile number length using string and exception handling

# %%
mobile = input ("enter mobile number\n")
if mobile.isdigit() and len(mobile)==10:
  print("valid mobile number")
else:
  print("invalid mobile number")
# Out:
# enter mobile number
# 98765432
# invalid mobile number

# %% [markdown]
# ex no:6
# 1.electricity bill calculation using user defined functiuon

# %%
def calculate_bill (units):
  if units<=100:
    return units*2
  else:
    return 100*2 + (units-100)+3
  units = int (input("enter unitd consumed\n"))
  print("total bill amount = $",calculate_bill(units))

# %% [markdown]
# 2.find the maxmium of three numbers using function

# %%
def maxmium(a,b,c):
  return max(a,b,c)
x=int(input("entre first number\n"))
y=int(input("enter second number\n"))
z=int(input("enter third number\n"))
print("maxmium number=",maxmium(x,y,z))
# Out:
# entre first number
# 10
# enter second number
# 25
# enter third number
# 15
# maxmium number= 25
